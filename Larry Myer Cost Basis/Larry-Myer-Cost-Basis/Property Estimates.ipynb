# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
cost_basis_file = "./Estimates.csv"

# %%
estimate = pd.read_csv(cost_basis_file)

# %%
estimate
# Out:
#   Property Address  Remove Brush,Trees and Trash Yard Front and Back  \
# 0   3629 Park KCMO                                              4000
#
#    Repair/Replace as Needed Roof, Soffits, and Facia  \
# 0                                               5500
#
#    Repair/Replace as needed Broken or Missing Windows  \
# 0                                               2500
#
#    Repair Defective Siding Exterior  Scrape and Paint Exterior  \
# 0                              2000                       3500
#
#    Install New Mast, Meter Can, and 100 amp House Panel  \
# 0                                               2000
#
#    Install Whole House Electric  \
# 0                          3750
#
#    Install Whole House Plumbing and Drain Lines as Needed  \
# 0                                               1750
#
#    Drywall Install and Repair  Texture Interior Whole House  \
# 0                        2500                          3800
#
# ...

# %%
park_3629 = estimate.loc[estimate["Property Address"] == "3629 Park KCMO"]

park_3629
# Out:
#   Property Address  Remove Brush,Trees and Trash Yard Front and Back  \
# 0   3629 Park KCMO                                              4000
#
#    Repair/Replace as Needed Roof, Soffits, and Facia  \
# 0                                               5500
#
#    Repair/Replace as needed Broken or Missing Windows  \
# 0                                               2500
#
#    Repair Defective Siding Exterior  Scrape and Paint Exterior  \
# 0                              2000                       3500
#
#    Install New Mast, Meter Can, and 100 amp House Panel  \
# 0                                               2000
#
#    Install Whole House Electric  \
# 0                          3750
#
#    Install Whole House Plumbing and Drain Lines as Needed  \
# 0                                               1750
#
#    Drywall Install and Repair  Texture Interior Whole House  \
# 0                        2500                          3800
#
# ...

# %%
cost = estimate["Total"]

cost
# Out:
# 0    53750
# Name: Total, dtype: int64

# %%
cost = estimate["Total"]
plt.title("Estimate Total")
plt.ylabel("Cost ($)")
plt.xlabel("Property Address")
plt.xticks(rotation=90)
plt.bar(park_3629, cost)

#plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5f0fbe6b8c7a> in <module>()
#       4 plt.xlabel("Property Address")
#       5 plt.xticks(rotation=90)
# ----> 6 plt.bar(park_3629, cost)
#       7
#       8 #plt.show
#
# C:\Users\jorda\Anaconda3\envs\pythondata\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
# -> 2489         **({"data": data} if data is not None else {}), **kwargs)
#    2490
#    2491
#
# C:\Users\jorda\Anaconda3\envs\pythondata\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
# ...

# %%
# Out:
# <AxesSubplot:>
