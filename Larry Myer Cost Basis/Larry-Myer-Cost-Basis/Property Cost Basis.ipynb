# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#data files
cost_basis_file = "./Cost_Basis_Per_Property.csv"
contractor_file = "./Contractor-Cost.csv"

# %%
#read data 
indiana = pd.read_csv(cost_basis_file)
contractor = pd.read_csv(contractor_file)

# %%
indiana.head()
# Out:
#                Property Address Electric (anything electrician does)  \
# 0  3532 Indiana Blvd KCMO 64128                            $3,987.37
#
#   Plumbing (anything plumber does)    Drywall Paint (interior)  \
# 0                        $2,000.00  $4,708.26        $6,371.02
#
#   Paint (exterior)     Siding    Roofing  Tree Work     Carpet  ...  \
# 0        $3,707.49  $8,418.66  $3,700.00  $3,000.00  $2,560.24  ...
#
#        Deck     Windows Gas line    Furnace Air Conditioning  Duct Work  \
# 0  $1,550.00  $3,481.61  $275.00  $4,350.00        $1,700.00  $1,125.00
#
#     Dumpster  Permits Water line and Meter Pit      Other
# 0  $1,030.00  $294.74                $6,000.00  $4,353.45
#
# [1 rows x 23 columns]

# %%
#Pie chart Cost Basis
Items = ["Electric (anything electrician does)", "Plumbing (anything plumber does)", "Drywall", "Paint (interior)", "Paint (exterior)", "Siding", "Roofing", "Tree Work", "Carpet", "Hardwood Floor", "Tile (floor/shower)", "Appliances", "Deck", "Windows", "Gas line", "Furnace", "Air Conditioning", "Duct Work", "Dumpster", "Permits", "Water line and Meter Pit", "Other"]
Cost = [3987.37, 2000.00, 4708.26, 6371.02, 3707.49, 8418.66, 3700.00, 3000.00, 2560.24, 0.00, 550.00, 1593.33, 1550.00, 3481.61, 275.00, 4350.00, 1700.00, 1125.00, 1030.00, 294.74, 6000.00, 4353.45]
colors = ["yellow", "pink", "green","lightblue","orange","red","purple"]
labels = ("Electric (anything electrician does)", "Plumbing (anything plumber does)", "Drywall", "Paint (interior)", "Paint (exterior)", "Siding", "Roofing", "Tree Work", "Carpet", "Hardwood Floor", "Tile (floor/shower)", "Appliances", "Deck", "Windows", "Gas line", "Furnace", "Air Conditioning", "Duct Work", "Dumpster", "Permits", "Water line and Meter Pit", "Other")
plt.pie(Cost, labels = labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("3532 Indiana Cost Basis")
plt.axis("equal")
plt.show()

# %%
#Scatter plot Cost Basis
Items = ["Electric (anything electrician does)", "Plumbing (anything plumber does)", "Drywall", "Paint (interior)", "Paint (exterior)", "Siding", "Roofing", "Tree Work", "Carpet", "Hardwood Floor", "Tile (floor/shower)", "Appliances", "Deck", "Windows", "Gas line", "Furnace", "Air Conditioning", "Duct Work", "Dumpster", "Permits", "Water line and Meter Pit", "Other"]
Cost = [3987.37, 2000.00, 4708.26, 6371.02, 3707.49, 8418.66, 3700.00, 3000.00, 2560.24, 0.00, 550.00, 1593.33, 1550.00, 3481.61, 275.00, 4350.00, 1700.00, 1125.00, 1030.00, 294.74, 6000.00, 4353.45]
plt.title("3532 Indiana Cost Basis")
plt.xlabel("Items")
plt.ylabel("Cost")
plt.xticks(rotation="vertical")
plt.grid()
plt.scatter(Items, Cost, marker="o", facecolors="blue", edgecolors="black")

# %%
contractor = pd.read_csv(contractor_file)
contractor
# Out:
#       Name  Total Cost
# 0     Tivo    19500.00
# 1    John      6175.00
# 2    Carl      2610.00
# 3  Preston     3464.82
# 4    Total    57762.02

# %%
#Pie chart Contractor Cost
Name= ["Name"]
Cost = [19500, 6175, 2610, 3464.82]
colors = ["yellow", "pink", "green","lightblue","orange"]
labels = ("Tivo", "John", "Carl", "Preston")
plt.pie(Cost, labels = labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("3532 Indiana Contractor Expense")
plt.axis("equal")
plt.show()
